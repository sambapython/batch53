# %%
f=open("data.txt","w")

# %%
f.write("Hello notepad, how are you?")
# Out:
# 27

# %%
f.close()

# %%
f.write("some datat")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-df21145c52ba> in <module>()
# ----> 1 f.write("some datat")
#
# ValueError: I/O operation on closed file.

# %%
f=open("data.txt","w")

# %%
f.write("Hello notepad, how are you?")
# Out:
# 27

# %%
f.flush()

# %%
f.write("some data")
# Out:
# 9

# %%
f.close()

# %%
f=open("data.txt","a")
f.write("\n this is appending after open a file in append mode")
f.close()

# %%
# name,age,sal
name=input("enter name:")
age=input("enter age:")
sal=input("Enter sal:")
row="%s,%s,%s\n"%(name,age,sal)
f=open("emp.txt","a")
f.write(row)
f.close()
# Out:
# enter name:jay
# enter age:23
# Enter sal:432543

# %%
# name,age,sal
name=input("enter name:")
age=input("enter age:")
sal=input("Enter sal:")
row="%s,%s,%s\n"%(name,age,sal)
f=open("emp.txt","a")
f.write(row)
f.close()
# Out:
# enter name:vedha
# enter age:23
# Enter sal:5346

# %%
# name,age,sal
name=input("enter name:")
age=input("enter age:")
sal=input("Enter sal:")
row="%s,%s,%s\n"%(name,age,sal)
f=open("emp.txt","a")
f.write(row)
f.close()
# Out:
# enter name:sai
# enter age:23
# Enter sal:456

# %%
f=open("emp.txt","r")
data=f.read()
print(data)
# Out:
# jay,23,432543
# vedha,23,5346
# sai,23,456

# %%
f=open("emp.txt","r")
data=f.read(10)
data1=f.read(10)
print(data)
print(data1)
# Out:
# jay,23,432
# 543
# vedha,

# %%
f=open("emp.txt","r")

# %%
f.read(10)
# Out:
# 'jay,23,432'

# %%
f.read(10)
# Out:
# '543\nvedha,'

# %%
f.read(10)
# Out:
# '23,5346\nsa'

# %%
f.read(10)
# Out:
# 'i,23,456\n'

# %%
f.read(10)
# Out:
# ''

# %%
f=open("emp.txt","r")

# %%
f.readline()
# Out:
# 'jay,23,432543\n'

# %%
f.readline()
# Out:
# 'vedha,23,5346\n'

# %%
f.readline()
# Out:
# 'sai,23,456\n'

# %%
f.readline()
# Out:
# ''

# %%
f=open("emp.txt","r")
f.readlines()
# Out:
# ['jay,23,432543\n', 'vedha,23,5346\n', 'sai,23,456\n']

# %%
f=open("emp.txt","r")
for row in f:
    print (row)
# Out:
# jay,23,432543
#
# vedha,23,5346
#
# sai,23,456

# %%
f=open("emp.txt","r")
for row in f:
    print (row.split(','))
# Out:
# ['jay', '23', '432543\n']
# ['vedha', '23', '5346\n']
# ['sai', '23', '456\n']

# %%
f=open("emp.txt","r")
for row in f:
    print (row.split(',')[0])
# Out:
# jay
# vedha
# sai

# %%
f=open("emp.txt","r")
for row in f:
    print (row.split(',')[-1])
# Out:
# 432543
#
# 5346
#
# 456

# %%
f=open("emp.txt","r")
for row in f:
    print (row.split(',')[-1].strip())
# Out:
# 432543
# 5346
# 456

# %%
f=open("emp.txt","r")
salaries=[]
for row in f:
    salaries.append(row.split(',')[-1].strip())
print (salaries)
# Out:
# ['432543', '5346', '456']

# %%
f=open("emp.txt","r")
salaries=[]
for row in f:
    salaries.append(int(row.split(',')[-1].strip()))
print (salaries)
# Out:
# [432543, 5346, 456]

# %%
f=open("emp.txt","r")
salaries=[]
for row in f:
    sal= row.split(',')[-1]
    sal_without_sace_cahar = sal.strip()
    sal_int=int(sal_without_sace_cahar)
    salaries.append(sal_int)
print (salaries)
# Out:
# [432543, 5346, 456]

# %%
f=open("emp.txt","r")
salaries=[]
for row in f:
    sal= row.split(',')[-1]
    sal_without_sace_cahar = sal.strip()
    sal_int=int(sal_without_sace_cahar)
    salaries.append(sal_int)
print (sum(salaries)/len(salaries))
# Out:
# 146115.0

# %%
f=open("emp.txt","r")
data=f.read()
f.close()
print(data)
data_new = data.replace(",23,",",26,")
print(data_new)
# Out:
# jay,23,432543
# vedha,24,5346
# sai,23,456
#
# jay,26,432543
# vedha,24,5346
# sai,26,456

# %%
f=open("emp.txt","r")
data=f.read()
f.close()
print(data)
data_new = data.replace(",23,",",26,")
print(data_new)
f=open("emp.txt","w")
f.write(data_new)
f.close()
# Out:
# jay,23,432543
# vedha,24,5346
# sai,23,456
#
# jay,26,432543
# vedha,24,5346
# sai,26,456

# %%
f=open("bahubali2.mp4","r")
f.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-44-cb8cfa33e37a> in <module>()
# ----> 1 f=open("bahubali2.mp4","r")
#       2 f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bahubali2.mp4'

# %%
f=open("exec.jpg","rb")
data=f.read()
f=open("bigfile.jpg","a")
for i in range(10):
    f.write(str(data))
    f.flush()
f.close()

# %%
pwd
# Out:
# '/home/khyaathipython/batch53'

# %%
f=open("data.json")
data=f.read()

# %%
print(data)
# Out:
# {
#     "glossary": {
#         "title": "example glossary",
# 		"GlossDiv": {
#             "title": "S",
# 			"GlossList": {
#                 "GlossEntry": {
#                     "ID": "SGML",
# 					"SortAs": "SGML",
# 					"GlossTerm": "Standard Generalized Markup Language",
# 					"Acronym": "SGML",
# 					"Abbrev": "ISO 8879:1986",
# 					"GlossDef": {
#                         "para": "A meta-markup language, used to create markup languages such as DocBook.",
# 						"GlossSeeAlso": ["GML", "XML"]
#                     },
# 					"GlossSee": "markup"
#                 }
#             }
#         }
#     }
# }

# %%
type(data)
# Out:
# str

# %%
f=open("data.yaml")
data=f.read()
print(data)
print(type(data))
# Out:
# ---
# environment: production
# classes:
#   nfs::server:
#     exports:
#       - /srv/share1
#       - /srv/share3
# parameters:
# <class 'str'>

# %%
f=open("data.yaml")
import yaml
data = yaml.load(f)
print(type(data))
# Out:
# <class 'dict'>

# %%
f=open("data.yaml")
import yaml
data = yaml.load(f)
print(data)
print(type(data))
# Out:
# {'environment': 'production', 'classes': {'nfs::server': {'exports': ['/srv/share1', '/srv/share3']}}, 'parameters': None}
# <class 'dict'>

# %%
data.get("environment")
# Out:
# 'production'

# %%
f=open("data.json")
import json
data = json.load(f)
print(data)
print(type(data))
# Out:
# {'glossary': {'title': 'example glossary', 'GlossDiv': {'title': 'S', 'GlossList': {'GlossEntry': {'ID': 'SGML', 'SortAs': 'SGML', 'GlossTerm': 'Standard Generalized Markup Language', 'Acronym': 'SGML', 'Abbrev': 'ISO 8879:1986', 'GlossDef': {'para': 'A meta-markup language, used to create markup languages such as DocBook.', 'GlossSeeAlso': ['GML', 'XML']}, 'GlossSee': 'markup'}}}}}
# <class 'dict'>

# %%
data.get("glossary")
# Out:
# {'title': 'example glossary',
#  'GlossDiv': {'title': 'S',
#   'GlossList': {'GlossEntry': {'ID': 'SGML',
#     'SortAs': 'SGML',
#     'GlossTerm': 'Standard Generalized Markup Language',
#     'Acronym': 'SGML',
#     'Abbrev': 'ISO 8879:1986',
#     'GlossDef': {'para': 'A meta-markup language, used to create markup languages such as DocBook.',
#      'GlossSeeAlso': ['GML', 'XML']},
#     'GlossSee': 'markup'}}}}

# %%
settings={"environment":"dev","datacenter":"west-india","plugin-ip":"192.168.0.1"}
f=open("settings.txt","w")
f.write(settings)
f.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-a2ee92dfbe8e> in <module>()
#       1 settings={"environment":"dev","datacenter":"west-india","plugin-ip":"192.168.0.1"}
#       2 f=open("settings.txt","w")
# ----> 3 f.write(settings)
#       4 f.close()
#
# TypeError: write() argument must be str, not dict

# %%
settings={"environment":"dev","datacenter":"west-india","plugin-ip":"192.168.0.1"}
f=open("settings.txt","w")
f.write(str(settings))
f.close()

# %%
f=open("settings.txt")
data=f.read()
print(data)
print(type(data))
# Out:
# {'environment': 'dev', 'datacenter': 'west-india', 'plugin-ip': '192.168.0.1'}
# <class 'str'>

# %%
data.get("environment")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-588b0717060d> in <module>()
# ----> 1 data.get("environment")
#
# AttributeError: 'str' object has no attribute 'get'

# %%
import pickle
settings={"environment":"dev","datacenter":"west-india","plugin-ip":"192.168.0.1"}
f=open("settings.txt","wb")
pickle.dump(settings,f)
f.close()

# %%
f=open("settings.txt","rb")
data=f.read()
print(data)
# Out:
# b'\x80\x03}q\x00(X\x0b\x00\x00\x00environmentq\x01X\x03\x00\x00\x00devq\x02X\n\x00\x00\x00datacenterq\x03X\n\x00\x00\x00west-indiaq\x04X\t\x00\x00\x00plugin-ipq\x05X\x0b\x00\x00\x00192.168.0.1q\x06u.'

# %%
f=open("settings.txt","rb")
data=pickle.load(f)
print(data)
print(type(data))
# Out:
# {'environment': 'dev', 'datacenter': 'west-india', 'plugin-ip': '192.168.0.1'}
# <class 'dict'>

# %%
import pickle
settings=[{"environment":"dev","datacenter":"west-india","plugin-ip":"192.168.0.1"},10,1+2j,"hi",(1,2,3,4)]
f=open("settings.txt","wb")
pickle.dump(settings,f)
f.close()
f=open("settings.txt","rb")
data=pickle.load(f)
print(data)
print(type(data))
# Out:
# [{'environment': 'dev', 'datacenter': 'west-india', 'plugin-ip': '192.168.0.1'}, 10, (1+2j), 'hi', (1, 2, 3, 4)]
# <class 'list'>

# %%
f=open("emp.txt","r")
data=f.read()
print(data)
# Out:
# jay,26,432543
# vedha,24,5346
# sai,26,456

# %%
data1=f.read()
print("data1=",data1)
# Out:
# data1=

# %%
f=open("emp.txt","r")
if f.read():
    data=f.read()
print(data)

# %%
f=open("emp.txt","r")
if f.read():
    print("data is there")
    data=f.read()
print(data)
# Out:
# data is there

# %%
f=open("emp.txt","r")
print(f.tell())
# Out:
# 0

# %%
data=f.read()

# %%
f.tell()
# Out:
# 39

# %%
data1=f.read()

# %%
f.seek(0)
# Out:
# 0

# %%
f.tell()
# Out:
# 0

# %%
f.read()
# Out:
# 'jay,26,432543\nvedha,24,5346\nsai,26,456\n'

# %%
f.tell()
# Out:
# 39

# %%
f.read()
# Out:
# ''

# %%
f.seek(10)
# Out:
# 10

# %%
f.tell()
# Out:
# 10

# %%
f.read()
# Out:
# '543\nvedha,24,5346\nsai,26,456\n'

# %%
data=open("int_mem.jpg","rb").read()
print(data)
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x05\x03\x04\x04\x04\x03\x05\x04\x04\x04\x05\x05\x05\x06\x07\x0c\x08\x07\x07\x07\x07\x0f\x0b\x0b\t\x0c\x11\x0f\x12\x12\x11\x0f\x11\x11\x13\x16\x1c\x17\x13\x14\x1a\x15\x11\x11\x18!\x18\x1a\x1d\x1d\x1f\x1f\x1f\x13\x17"$"\x1e$\x1c\x1e\x1f\x1e\xff\xdb\x00CX\x03 \x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19
# ...

# %%
data=open("int_mem.jpg","rb").read()
f=open("int_mem_copy.jpg","wb")
f.write(data)
f.close()

# %%
#opencv
import OpenCv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-46-24fb48db3cf7> in <module>()
#       1 #opencv
# ----> 2 import OpenCv
#
# ModuleNotFoundError: No module named 'OpenCv'

# %%
import cv2 as cv
print(cv.__version__)
# Out:
# 4.0.0

# %%
print(dir(cv))
# Out:
# ['', 'ACCESS_FAST', 'ACCESS_MASK', 'ACCESS_READ', 'ACCESS_RW', 'ACCESS_WRITE', 'ADAPTIVE_THRESH_GAUSSIAN_C', 'ADAPTIVE_THRESH_MEAN_C', 'AGAST_FEATURE_DETECTOR_AGAST_5_8', 'AGAST_FEATURE_DETECTOR_AGAST_7_12D', 'AGAST_FEATURE_DETECTOR_AGAST_7_12S', 'AGAST_FEATURE_DETECTOR_NONMAX_SUPPRESSION', 'AGAST_FEATURE_DETECTOR_OAST_9_16', 'AGAST_FEATURE_DETECTOR_THRESHOLD', 'AKAZE', 'AKAZE_DESCRIPTOR_KAZE', 'AKAZE_DESCRIPTOR_KAZE_UPRIGHT', 'AKAZE_DESCRIPTOR_MLDB', 'AKAZE_DESCRIPTOR_MLDB_UPRIGHT', 'AKAZE_create', 'AgastFeatureDetector', 'AgastFeatureDetector_AGAST_5_8', 'AgastFeatureDetector_AGAST_7_12d', 'AgastFeatureDetector_AGAST_7_12s', 'AgastFeatureDetector_NONMAX_SUPPRESSION', 'AgastFeatureDetector_OAST_9_16', 'AgastFeatureDetector_THRESHOLD', 'AgastFeatureDetector_create', 'Algorithm', 'AlignExposures', 'AlignMTB', 'BFMatcher', 'BFMatcher_create', 'BORDER_CONSTANT', 'BORDER_DEFAULT', 'BORDER_ISOLATED', 'BORDER_REFLECT', 'BORDER_REFLECT101', 'BORDER_REFLECT_101', 'BORDER_REPLICATE', 'BORDER_
# ...

# %%
img = cv.imread("init_mem.jpg")

# %%
print(dir(img))
# Out:
# ['__bool__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__']

# %%
print(img)
# Out:
# None

# %%
cv.transpose(src="init_mem.jpg")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-a45fc5c99fe2> in <module>()
# ----> 1 cv.transpose(src="init_mem.jpg")
#
# TypeError: Expected cv::UMat for argument 'src'
